# %% [markdown]
# <center>
#     <img src="https://s3-api.us-geo.objectstorage.softlayer.net/cf-courses-data/CognitiveClass/Logos/organization_logo/organization_logo.png" width="300" alt="cognitiveclass.ai logo"  />
# </center>

# %% [markdown]
# #### Add your code below following the instructions given in the course

# %% [markdown]
# My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# **Meixia Zhang**
# <br>Environmental Data Analyst

# %% [markdown]
# *I am interested in data science because data is interesting.*

# %% [markdown]
# Here is some codes about performing the type-II regressions (standard major axis regression) with the pacakge of *smatr* in R.

# %%
print(1+1)
# Out:
# [1] 2

# %%
data.frame(c("A","B","C"),matrix(c(1:6),nrow=3,ncol=2))
# Out:
#   c..A....B....C.. X1 X2
# 1 A                1  4
# 2 B                2  5
# 3 C                3  6

# %%
v1<-c(5,6,7)
v2<-c(v1,8)
print(v1)
print(v2)
# Out:
# [1] 5 6 7
# [1] 5 6 7 8

# %%
install.packages("smatr")
library(smatr)
a<-c(1,4,3,4,5,6,7,8)
b<-c(2,4,6,8,10,12,14,16)
par(las=1,tcl=0.2)
plot(a,b,pch=19,col="blue",xlab="",ylab="")
abline(sma(b~a),col="red")
text(3.5,14,"I am Meixia. How are you?",col="red",cex=1.5,lwd=2)
# Out:
# Updating HTML index of packages in '.Library'
# Making 'packages.html' ... done
# plot without title

# %% [markdown]
# >Codes above are about the simple regression, hope that it is not so bad
# <hr>
# <ol>
# <li>library</li>
# <li>plot</li>
# <li>abline</li>
# <li>text</li>
# </ol>
# <hr>
# <br>
# <ul>
# <li>library</li>
# <li>plot</li>
# <li>abline</li>
# <li>text</li>
# </ul>
#
# <!-- [Text](link) -->
#
# [Smatr package R](https://cran.r-project.org/package=smatr " Title (smatr)")
